# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache using fc-list. This may take a moment.

# %%
plt.figure(figsize=(10, 10))
plotLoss = [2.6591, 1.6761, 1.0372, 0.6690, 0.4511, 0.3317, 0.2503, 0.2053, 0.1579, 0.1443, 0.1361, 0.1242, 0.1212, 0.1144, 0.1095]
plotPercent = ['6%', '13%', '20%', '26%', '33%', '40%', '46%', '53%', '60%', '66%', '73%', '80%', '86%', '93%', '100%']
plt.plot(plotLoss, 'o-')
plt.xticks(range(len(plotLoss)), plotPercent, rotation=30, horizontalalignment='right')
plt.xlabel('Training Percent')
plt.ylabel('Loss Value')
plt.grid(True)
plt.title('Training Loss')
plt.show()
